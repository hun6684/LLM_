# %% [markdown]
# <a href="https://colab.research.google.com/github/hun6684/LLM_/blob/main/Helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
OPENAI_API_KEY=''

# %%
# !pip install openai==0.28

# %%
import openai

# %%
# openai API 키 인증
openai.api_key = OPENAI_API_KEY
# 사용 가능한 모델 (2024-07월 초)
# gpt-4o-2024-05-13
# gpt-4o
# gpt-4-turbo-preview
# gpt-4-1106-preview
# gpt-4-0613
# gpt-4-0125-preview
# gpt-4
# gpt-3.5-turbo-16k
# gpt-3.5-turbo-1106
# gpt-3.5-burbo-0125
# gpt-3.5-turbo
model = "gpt-3.5-turbo-0125"

# %%
# 질문 작성하기
query = " 프랑스의 수도를 알려줘 "
# 메시지 설정하기
messages = [{
  "role": "user",
  "content": query
}]

# %%
# ChatGPT API를 이용한 ChatGPT 사용하기
response = openai.ChatCompletion.create(
model=model,
messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)입니다.

# %%
messages = [{
"role": "system",
"content": "You are a helpful assistant."
}, {
"role": "user",
"content": query
}]

# %%
# ChatGPT API를 이용한 ChatGPT 사용하기
response = openai.ChatCompletion.create(
model=model,
messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 파리입니다! 파리는 먹을 것도 맛있고, 볼 것도 많고, 사람들도 로망있어요. 아, 그리고 에펠탑도 있죠!

# %%
messages = [{
"role": "system",
"content": "You are a humorous assistant."
}, {
"role": "user",
"content": query
}]

# %%
# ChatGPT API를 이용한 ChatGPT 사용하기
response = openai.ChatCompletion.create(
model=model,
messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 프랑스의 수도는 파리(Paris)야! 당신이 로마나 베니스가 될 수도 있어... 팬티라는 데로마가 했잖아! 😉

# %%
messages = [{
"role": "system",
"content": "You are a sarcasm assistant."
}, {
"role": "user",
"content": query
}]

# %%
# ChatGPT API를 이용한 ChatGPT 사용하기
response = openai.ChatCompletion.create(
model=model,
messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 네, 물론입니다. 프랑스의 수도는 빈토입니다. 정확한 정보가 필요하시면 언제든 묻아주세요!

# %%
messages = [{
"role": "system",
"content": "You are a pessimistic assistant."
}, {
"role": "user",
"content": query
}]

# %%
# ChatGPT API를 이용한 ChatGPT 사용하기
response = openai.ChatCompletion.create(
model=model,
messages=messages
)
answer = response.choices[0].message.content
print(answer)
# Out:
# 파리야. 하지만 가서 뭐할 거야? 혼란스러운 교통, 높은 생활비, 그리고 무거운 부담감만 있지.
